# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from numpy import percentile
import datetime as dt
import matplotlib.pyplot as plt

plt.style.use({'figure.facecolor': 'white'})
from sklearn.preprocessing import StandardScaler
from pyod.models.pca import PCA
from pyod.models.hbos import HBOS
from pyod.models.abod import ABOD
from pyod.models.lof import LOF
from pyod.models.iforest import IForest
from pyod.models.lscp import LSCP

# %% [markdown]
# ### Data Import

# %%
df = pd.read_csv('../../data/dataset.csv', parse_dates=['datetime'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131184 entries, 0 to 131183
# Data columns (total 7 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   ou        131184 non-null  float64
#  1   datetime  131184 non-null  datetime64[ns]
#  2   cheques   131184 non-null  int64
#  3   rto       131184 non-null  float64
#  4   n_sku     131184 non-null  int64
#  5   cnt       131184 non-null  int64
#  6   cashnum   131184 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(4)
# memory usage: 7.0 MB

# %%
df.head()
# Out:
#       ou            datetime  cheques      rto  n_sku  cnt  cashnum
# 0  468.0 2019-11-16 08:00:00       34   8003.0    137  173        3
# 1  468.0 2019-11-16 09:00:00       40  20129.0    283  517        2
# 2  468.0 2019-11-16 10:00:00       41  15782.0    185  227        2
# 3  468.0 2019-11-16 11:00:00       63  39451.0    386  659        4
# 4  468.0 2019-11-16 12:00:00       84  57330.0    635  992        4

# %% [markdown]
# ### Visualization timeseries

# %%
def show_plots(df, columns, anomaly_column=None):
    fig, axs = plt.subplots(len(columns), 1, sharex=True, constrained_layout=True, figsize=(12, 10))
    for i in range(len(columns)):
        c = columns[i]

        axs[i].plot(dd.index, df[c], color='gray', label='Normal')

        if anomaly_column:
            a = df.loc[df[anomaly_column] == 1, [c]]  #anomaly
            axs[i].scatter(a.index, a[c], color='red', label='Anomaly')

        axs[i].xaxis_date()
        axs[i].set_title(c)
        plt.xlabel('Date')
    plt.show()

# %%
columns = ['rto', 'cheques', 'n_sku', 'cnt', 'cashnum']
for ou in df['ou'].unique()[:1]:
    dd = df[df['ou'] == ou]
    dd = dd.set_index('datetime')['2021-01-01':'2022-03-15']
    dd = dd[columns].resample('D').sum()

    show_plots(dd, columns)

# %%
outliers_fraction = 0.05
random_state = np.random.RandomState(42)

# %% [markdown]
# ### LSCP

# %%
detector_list = [
    PCA(contamination=outliers_fraction, random_state=random_state),
    HBOS(contamination=outliers_fraction),
    LOF(contamination=outliers_fraction),
    ABOD(contamination=outliers_fraction),
    IForest(contamination=outliers_fraction, random_state=random_state)
]

lscp_detector = LSCP(detector_list, contamination=outliers_fraction, random_state=random_state)

# %%
for ou in df.ou.unique():
    dd = df[df.ou == ou]
    dd = dd.set_index('datetime')
    dd = dd[columns].resample('D').sum()

    X = dd.values
    lscp_detector.fit(X)

    pred = lscp_detector.predict(X)

    dd['anomaly'] = pred

    show_plots(dd, columns, 'anomaly')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-52734dc32f2d> in <module>
#       5
#       6     X = dd.values
# ----> 7     lscp_detector.fit(X)
#       8
#       9     pred = lscp_detector.predict(X)
#
# ~\.conda\envs\DS\lib\site-packages\pyod\models\lscp.py in fit(self, X, y)
#     174
#     175         # set decision scores and threshold
# --> 176         self.decision_scores_ = self._get_decision_scores(X)
#     177         self._process_decision_scores()
#     178
#
# ~\.conda\envs\DS\lib\site-packages\pyod\models\lscp.py in _get_decision_scores(self, X)
#     247         # generate standardized scores
#     248         train_scores_norm, test_scores_norm = standardizer(self.train_scores_,
# --> 249                                                            test_scores)
#     250
#     251         # generate pseudo target for training --> for calculating weights
#
# ~\.conda\envs\DS\lib\site-packages\pyod\utils\utility.py in standardizer(X, X_t, keep_scalar)
#     152
#     153     """
# --> 154     X = check_array(X)
#     155     scaler = StandardScaler().fit(X)
#     156
#
# ~\.conda\envs\DS\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\.conda\envs\DS\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     662         if force_all_finite:
#     663             _assert_all_finite(array,
# --> 664                                allow_nan=force_all_finite == 'allow-nan')
#     665
#     666     if ensure_min_samples > 0:
#
# ~\.conda\envs\DS\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     104                     msg_err.format
#     105                     (type_err,
# --> 106                      msg_dtype if msg_dtype is not None else X.dtype)
#     107             )
#     108     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
